# %%
# !cd /content/drive/MyDrive/NYU/Sem3/DeepLearning/Files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r '/content/drive/MyDrive/NYU/Sem3/DeepLearning/Files/TTS/requirements.txt'
# Out:
# ...
#      |████████████████████████████████| 14.8 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 183 kB 83.4 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 49.5 MB/s
# ...
#      |████████████████████████████████| 287 kB 78.5 MB/s
# ...
#      |████████████████████████████████| 136 kB 78.7 MB/s
# ...
#      |████████████████████████████████| 71 kB 11.8 MB/s
# ...
#      |████████████████████████████████| 80 kB 13.0 MB/s
# ...
#      |████████████████████████████████| 125 kB 80.5 MB/s
# ...
#      |████████████████████████████████| 212 kB 101.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 40 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 65.8 MB/s
# ...
#      |████████████████████████████████| 487 kB 89.7 MB/s
# ...
#      |████████████████████████████████| 47.4 MB 251 kB/s
# ...
#      |████████████████████████████████| 73 kB 2.7 MB/s
# ...

# %%
# !pip install numpy==1.21.5
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 3.8 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# !CUDA_VISIBLE_DEVICES="0" python /content/drive/MyDrive/NYU/Sem3/DeepLearning/Files/TTS/recipes/ljspeech/tacotron2-DDC/train_tacotron_ddc.py
# !CUDA_VISIBLE_DEVICES="0" python /content/recipie.py
# !CUDA_VISIBLE_DEVICES="0" python /content/drive/MyDrive/NYU/Sem3/DeepLearning/Files/TTS/train_tacotron_ddc.py
# Out:
# Streaming output truncated to the last 5000 lines.
#  | > Max audio length: 222643.0
#  | > Min audio length: 24499.0
#  | > Avg audio length: 144984.29755570978
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > TRAINING (2022-05-15 00:06:36)
#
#    --> STEP: 24/203 -- GLOBAL_STEP: 3475
#      | > decoder_loss: 23.81355  (23.90395)
#      | > postnet_loss: 26.23973  (26.32263)
#      | > stopnet_loss: 0.57191  (0.71577)
#      | > decoder_coarse_loss: 23.23318  (23.34365)
#      | > decoder_ddc_loss: 0.00401  (0.00533)
#      | > ga_loss: 0.00600  (0.00824)
#      | > decoder_diff_spec_loss: 0.97909  (0.93587)
#      | > postnet_diff_spec_loss: 5.72503  (5.71558)
#      | > decoder_ssim_loss: 0.98532  (0.97620)
#      | > postnet_ssim_loss: 0.98990  (0.97998)
#      | > loss: 21.09435  (21.30276)
#      | > align_error: 0.98068  (0.97483)
#      | > grad_norm: 5.46882  (5.95686)
#      | > current_lr: 0.00000
#      | > step_time: 1.05750  (1.01387)
# ...
