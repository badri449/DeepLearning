# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/DLspring2022FinalProject
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject

# %%
# !pwd
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject

# %%
# !pip install TTS
# Out:
# ...
#      |████████████████████████████████| 1.3 MB 4.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 125 kB 67.7 MB/s
# ...
#      |████████████████████████████████| 287 kB 71.7 MB/s
# ...
#      |████████████████████████████████| 80 kB 283 kB/s
# ...
#      |████████████████████████████████| 3.4 MB 61.4 MB/s
# ...
#      |████████████████████████████████| 47.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 40 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 73 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 71 kB 9.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 45.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 183 kB 62.2 MB/s
# ...
#      |████████████████████████████████| 487 kB 35.8 MB/s
# ...

# %%
# !pip install numpy==1.21.5
# !pip install pandas

# %%
# !pwd
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject

# %%
# !pwd
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject

# %%
#!git clone https://github.com/coqui-ai/TTS
# Out:
# Cloning into 'TTS'...
# remote: Enumerating objects: 26960, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (183/183), done.
# remote: Total 26960 (delta 181), reused 182 (delta 112), pack-reused 26660
# Receiving objects: 100% (26960/26960), 128.35 MiB | 13.81 MiB/s, done.
# Resolving deltas: 100% (19671/19671), done.
# Checking out files: 100% (509/509), done.

# %%
# !ls
# Out:
# TTS

# %%
# %cd /content/drive/MyDrive/DLspring2022FinalProject/TTS
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject/TTS

# %%
# !pwd
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject/TTS

# %%
# !ls
# Out:
# build		    docs	 pyproject.toml		     setup.cfg
# CITATION.cff	    hubconf.py	 README.md		     setup.py
# CODE_OF_CONDUCT.md  images	 recipes		     tests
# CODE_OWNERS.rst     LICENSE.txt  requirements.dev.txt	     TTS
# CONTRIBUTING.md     Makefile	 requirements.notebooks.txt  TTS.egg-info
# datasets	    MANIFEST.in  requirements.txt	     tts_output.wav
# Dockerfile	    notebooks	 run_bash_tests.sh

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/DLspring2022FinalProject/TTS'

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/DLspring2022FinalProject/TTS
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.3 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 40 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 47.4 MB 276 kB/s
# ...
#      |████████████████████████████████| 1.3 MB 58.0 MB/s
# ...
#      |████████████████████████████████| 73 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 574 kB 69.4 MB/s
# ...
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# ...
#      |████████████████████████████████| 80 kB 12.1 MB/s
# ...
#      |████████████████████████████████| 73 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 125 kB 75.5 MB/s
# ...
#      |████████████████████████████████| 136 kB 85.7 MB/s
# ...
#      |████████████████████████████████| 183 kB 94.1 MB/s
# ...
#      |████████████████████████████████| 71 kB 11.2 MB/s
# ...

# %%
# !tts --list_models
# Out:
#  Name format: type/language/dataset/model
#  1: tts_models/multilingual/multi-dataset/your_tts
#  2: tts_models/en/ek1/tacotron2
#  3: tts_models/en/ljspeech/tacotron2-DDC
#  4: tts_models/en/ljspeech/tacotron2-DDC_ph
#  5: tts_models/en/ljspeech/glow-tts
#  6: tts_models/en/ljspeech/speedy-speech
#  7: tts_models/en/ljspeech/tacotron2-DCA
#  8: tts_models/en/ljspeech/vits
#  9: tts_models/en/ljspeech/fast_pitch
#  10: tts_models/en/vctk/vits
#  11: tts_models/en/vctk/fast_pitch
#  12: tts_models/en/sam/tacotron-DDC
#  13: tts_models/es/mai/tacotron2-DDC
#  14: tts_models/fr/mai/tacotron2-DDC
#  15: tts_models/uk/mai/glow-tts
#  16: tts_models/zh-CN/baker/tacotron2-DDC-GST
#  17: tts_models/nl/mai/tacotron2-DDC
#  18: tts_models/de/thorsten/tacotron2-DCA
#  19: tts_models/ja/kokoro/tacotron2-DDC
#  20: tts_models/tr/common-voice/glow-tts
#  21: tts_models/it/mai_female/glow-tts
#  22: tts_models/it/mai_female/vits
#  23: tts_models/it/mai_male/glow-tts
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !tts --text "Text for TTS"

# %%
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio

# %%
#!tts --text "The cat is jumping on the ball and making silly noises" --model_name "tts_models/en/ljspeech/tacotron2-DDC"
# Out:
#  > tts_models/en/ljspeech/tacotron2-DDC is already downloaded.
#  > vocoder_models/en/ljspeech/hifigan_v2 is already downloaded.
#  > Using model: Tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
# ...

# %%
Audio("tts_output.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %cd /content/drive/MyDrive/DLspring2022FinalProject/TTS/datasets
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject/TTS/datasets

# %%
# !pwd
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject/TTS/datasets

# %%
# %cd /content
# Out:
# /content

# %%
#!wget https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2
# Out:
# --2022-05-16 14:16:54--  https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2
# Resolving data.keithito.com (data.keithito.com)... 174.138.79.61
# Connecting to data.keithito.com (data.keithito.com)|174.138.79.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2748572632 (2.6G) [application/octet-stream]
# Saving to: ‘LJSpeech-1.1.tar.bz2’
#
# LJSpeech-1.1.tar.bz 100%[===================>]   2.56G  13.4MB/s    in 3m 25s
#
# 2022-05-16 14:20:21 (12.8 MB/s) - ‘LJSpeech-1.1.tar.bz2’ saved [2748572632/2748572632]

# %%
#!cp -r /content/LJSpeech-1.1.tar.bz2 /content/drive/MyDrive/DLspring2022FinalProject/TTS/datasets

# %%
 #!tar -xf /content/drive/MyDrive/DLspring2022FinalProject/TTS/datasets/LJSpeech-1.1.tar.bz2

# %%
 #!cp -r /content/LJSpeech-1.1 /content/drive/MyDrive/DLspring2022FinalProject/TTS/datasets/

# %%
# %cd /content/drive/MyDrive/DLspring2022FinalProject/TTS
# Out:
# /content/drive/MyDrive/DLspring2022FinalProject/TTS

# %%
# !pwd
# Out:
# /content

# %%
# !CUDA_VISIBLE_DEVICES="0" python /content/drive/MyDrive/DLspring2022FinalProject/TTS/recipes/ljspeech/tacotron2-DDC/train_tacotron_ddc.py
# /content/TTS/recipes/ljspeech/tacotron2-DDC/train_tacotron_ddc.py
# Out:
# Streaming output truncated to the last 5000 lines.
#      | > decoder_coarse_loss: 33.25840  (32.38727)
#      | > decoder_ddc_loss: 0.00252  (0.00361)
#      | > ga_loss: 0.00481  (0.00714)
#      | > decoder_diff_spec_loss: 0.45066  (0.44741)
#      | > postnet_diff_spec_loss: 4.25533  (4.26641)
#      | > decoder_ssim_loss: 0.99573  (0.99309)
#      | > postnet_ssim_loss: 0.99563  (0.99290)
#      | > loss: 27.99666  (27.37514)
#      | > align_error: 0.98581  (0.97995)
#      | > amp_scaler: 131072.00000  (131072.00000)
#      | > grad_norm: 3.33677  (3.14447)
#      | > current_lr: 0.00000
#      | > step_time: 1.39140  (1.34096)
#      | > loader_time: 0.01100  (0.01592)
#
#
#    --> STEP: 67/203 -- GLOBAL_STEP: 2300
#      | > decoder_loss: 33.45774  (32.62682)
#      | > postnet_loss: 35.40846  (34.54530)
#      | > stopnet_loss: 0.82481  (0.86456)
#      | > decoder_coarse_loss: 33.38527  (32.59181)
#      | > decoder_ddc_loss: 0.00210  (0.00309)
# ...

# %%
# !tts --text "Text for TTS checking for this" \
      --model_path "/content/drive/MyDrive/NYU/Sem3/DeepLearning/Files/output/run-May-10-2022_05+17AM-0000000/best_model.pth" \
      --config_path "/content/drive/MyDrive/NYU/Sem3/DeepLearning/Files/output/run-May-10-2022_05+17AM-0000000/config.json" \
      --out_path "/content/drive/MyDrive/NYU/Sem3/DeepLearning/Files/output/output.wav"
# Out:
#  > Using model: tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Model's reduction rate `r` is set to: 6
#  > Using Griffin-Lim as no vocoder model defined
#  > Text: Text for TTS checking for this
# ...
